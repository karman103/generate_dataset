# %% [markdown]
# # 1. Getting VizDoom Up and Running

# %%
# !pip install vizdoom
# Out:
# Requirement already satisfied: vizdoom in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.2.4)
# Requirement already satisfied: numpy in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from vizdoom) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from vizdoom) (1.0.0)
# Requirement already satisfied: pygame>=2.1.3 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from vizdoom) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)

# %%
# !cd github & git clone https://github.com/mwydmuch/ViZDoom
# Out:
# zsh:cd:1: no such file or directory: github
# fatal: destination path 'ViZDoom' already exists and is not an empty directory.

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('VizDoom/scenarios/defend_the_center.cfg')
game.init()
# Out:
# 2025-01-26 15:15:19.371 vizdoom[22817:10264033] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-26 15:15:19.371 vizdoom[22817:10264033] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([ 26., 100.])

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 2.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: -1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: -1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: -1.0
# Result: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 18
#      16     # Print rewward
#      17     print('reward:', reward)
# ---> 18     time.sleep(0.02)
#      19 print('Result:', game.get_total_reward())
#      20 time.sleep(2)
#
# KeyboardInterrupt:

# %%
game.close()

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gym) (0.0.8)

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('VizDoom/scenarios/defend_the_center.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)
# Out:
# 2025-01-26 15:16:34.656 vizdoom[22829:10264998] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-26 15:16:34.656 vizdoom[22829:10264998] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
state = env.reset()

# %% [markdown]
# # 3. View Game State

# %%
env.reset()
# Out:
# array([[[ 5],
#         [10],
#         [ 7],
#         ...,
#         [ 4],
#         [ 6],
#         [10]],
#
#        [[ 3],
#         [ 3],
#         [ 4],
#         ...,
#         [ 5],
#         [ 3],
#         [ 7]],
#
#        [[11],
#         [ 7],
#         [10],
#         ...,
#         [ 9],
#         [ 6],
#         [ 6]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 env_checker.check_env(env)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:429, in check_env(env, warn, skip_render_check)
#     414 def check_env(env: gym.Env, warn: bool = True, skip_render_check: bool = True) -> None:
#     415     """
#     416     Check that an environment follows Gym API.
#     417     This is particularly useful when using a custom environment.
#    (...)
#     427         True by default (useful for the CI)
#     428     """
# --> 429     assert isinstance(
#     430         env, gym.Env
#     431     ), "Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/"
#     433     # ============= Check the spaces (observation and action) ================
#     434     _check_spaces(env)
#
# AssertionError: Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/

# %% [markdown]
# # 3. View State

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/karman/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# # 4. Setup Callback

# %%
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.10.1+cu113 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.10.1+cu113

# %%
# !pip install stable-baselines3[extra]
# Out:
# zsh:1: no matches found: stable-baselines3[extra]

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_defend'
LOG_DIR = './logs/log_defend'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Model

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=90000, callback=callback)
# Out:
# Logging to ./logs/log_defend/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.8     |
# |    ep_rew_mean     | 0.489    |
# | time/              |          |
# |    fps             | 35       |
# |    iterations      | 1        |
# |    time_elapsed    | 116      |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97          |
# |    ep_rew_mean          | 1.27        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 2           |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012527464 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00355     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 1.87         |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 3            |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0116887875 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0156      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0285      |
# |    value_loss           | 0.116        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 2.71         |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 4            |
# |    time_elapsed         | 612          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0152588645 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0161      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0313      |
# |    value_loss           | 0.118        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | 3.29        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 5           |
# |    time_elapsed         | 774         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018186212 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00944     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 4.24        |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 6           |
# |    time_elapsed         | 3566        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.020350195 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0214     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 4.75        |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 7           |
# |    time_elapsed         | 3726        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018275043 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00651    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 5.33        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 8           |
# |    time_elapsed         | 3887        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024060996 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0311      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 5.8         |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 9           |
# |    time_elapsed         | 4048        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.023503933 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0216      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 6.28        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 10          |
# |    time_elapsed         | 4209        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.023703594 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00343    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 0.186       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 6.76        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 11          |
# |    time_elapsed         | 4402        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025881024 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0156      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 0.209       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 7.2         |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 4565        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024407014 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0579      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 0.185       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 164        |
# |    ep_rew_mean          | 7.84       |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 13         |
# |    time_elapsed         | 4730       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02798884 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.768     |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0139    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0396    |
# |    value_loss           | 0.198      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | 8.49        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 14          |
# |    time_elapsed         | 4913        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025853716 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0196     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | 8.94        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 15          |
# |    time_elapsed         | 5076        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.026714388 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.038      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 9.29        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 16          |
# |    time_elapsed         | 5241        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025735606 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0355     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | 9.86        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 17          |
# |    time_elapsed         | 5404        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.032723635 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00431     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | 10.2       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 18         |
# |    time_elapsed         | 5573       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02647606 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.61      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0368    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0388    |
# |    value_loss           | 0.162      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 5739        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.027767617 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0244     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 11.4        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 20          |
# |    time_elapsed         | 5910        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028220665 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0426     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | 12.2        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 21          |
# |    time_elapsed         | 6085        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.028150862 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0229     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 0.137       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 22          |
# |    time_elapsed         | 6266        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.029217117 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0224     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 0.135       |
# -----------------------------------------

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('train/train_defend/best_model_90000.zip')

# %%
# Create rendered environment
env = VizDoomGym(render=True)
# Out:
# 2025-01-26 20:56:55.641 vizdoom[27068:10532536] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-26 20:56:55.641 vizdoom[27068:10532536] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# ---------------------------------------------------------------------------
# ViZDoomUnexpectedExitException            Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Evaluate mean reward for 10 games
# ----> 2 mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/shimmy/openai_gym_compatibility.py:250, in GymV21CompatibilityV0.step(self, action)
#     241 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     242     """Steps through the environment.
#     243
#     244     Args:
#    (...)
#     248         (observation, reward, terminated, truncated, info)
#     249     """
# --> 250     obs, reward, done, info = self.gym_env.step(action)
#     252     if self.render_mode is not None:
#     253         self.render()
#
# Cell In[12], line 28, in VizDoomGym.step(self, action)
#      25 def step(self, action):
#      26     # Specify action and take step
#      27     actions = np.identity(3)
# ---> 28     reward = self.game.make_action(actions[action], 4)
#      30     # Get all the other stuff we need to retun
#      31     if self.game.get_state():
#
# ViZDoomUnexpectedExitException: Controlled ViZDoom instance exited unexpectedly.

# %%
mean_reward
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 mean_reward
#
# NameError: name 'mean_reward' is not defined

# %%
model.predict(obs)

# %%
for episode in range(5): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        # time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
